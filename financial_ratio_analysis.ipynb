# %% [markdown]
# # SK hynix Financial Ratio Analysis
# DART XBRL → 주요 재무데이터 → 재무비율 계산

# %%
import pandas as pd
df = pd.read_csv('../data/financial_data.csv')
df[['year','revenue','operating_income','net_income','assets','liabilities','equity','cfo','fcf','net_debt']]

# %%
ratio = pd.read_csv('../data/financial_ratios.csv')
ratio[['year','revenue_growth','operating_margin','net_margin','roa','roe','current_ratio','debt_to_equity','net_debt_to_ebitda']]
